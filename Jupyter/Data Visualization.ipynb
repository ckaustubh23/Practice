# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### SCATTER PLOT

# %%
from matplotlib import pyplot as plt
import numpy as np

# y_points = np.array([3, 8, 1, 10])
x = [3,5,2,9]
y = [1,2,3,4]
plt.plot(x,y)

# %%
# xpoints = np.array([33, 19, 33, 19, 33])
ypoints = np.array([35,9,26,9,35])
plt.plot(ypoints, marker = "*")
plt.plot(ypoints)

# %%
ypoints = np.array([0,5,5,0,9,26,9,35])
plt.plot(ypoints, marker = "*")
plt.plot(ypoints)

# %%
ypoints = np.array([0,7,10,10,7,0,27,30,30,27,0,55,60,60,55,0,27,30,30,27,0,17,20,20,17,0])
plt.plot(ypoints)

# %% [markdown]
# # 4 steps of model building
# * specify x and y
# * split data into 1) train 2) test
# * model building

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\PRADEEP\\Desktop\\kc code unnati'

# %% [markdown]
# # New Model

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("diabetes (1).csv")

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148            500             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672  102        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.sample(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 58             0      146             82              0        0  40.5
# 333           12      106             80              0        0  23.6
# 686            3      130             64              0        0  23.1
# 170            6      102             82              0        0  30.8
# 427            1      181             64             30      180  34.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 58                      1.781   44        0
# 333                     0.137   44        0
# 686                     0.314   22        0
# 170                     0.180   36        1
# 427                     0.328   38        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000   768.000000     768.000000     768.000000  768.000000
# mean      3.845052   122.242188      69.662760      20.536458   79.799479
# std       3.369578    49.001676      24.827374      15.952218  115.244002
# min       0.000000     0.000000       0.000000       0.000000    0.000000
# 25%       1.000000    99.000000      62.000000       0.000000    0.000000
# 50%       3.000000   117.000000      72.000000      23.000000   30.500000
# 75%       6.000000   141.000000      80.000000      32.000000  127.250000
# max      17.000000  1150.000000     500.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.308594    0.348958
# std      7.884160                  0.331329   11.998145    0.476951
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df["BMI"] = df["BMI"].astype('int')

# %%
df

# %%
df["BMI"] = df["BMI"].astype('int')
df.head

# %% [markdown]
# # Specify your X and y

# %%
x = df.drop('BMI', axis = 1)
# axis = 1 is for the columns
x.head()

# %%
y = df['BMI']

# %%
y

# %% [markdown]
# # Split your data into training and testing

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.35, random_state=10)

# %%
df.shape
# Out:
# (768, 9)

# %%
X_train = np.array(X_train)

# %%
X_train.shape
# Out:
# (2,)

# %%
Y_train
# Out:
# [4, 2]

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
# Out:
# C:\Users\PRADEEP\yash\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 y_pred = lr.predict(X_test)
#
# File ~\yash\Lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File ~\yash\Lib\site-packages\sklearn\linear_model\_base.py:369, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
#     367     check_is_fitted(self)
# ...

# %%
y_pred.shape
# Out:
# (269,)

# %%
Y_test.shape
# Out:
# (269,)

# %% [markdown]
# # Model Performance

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
r2 = r2_score(y_pred,Y_test)

# %%
r2
# Out:
# -19.369413879956216
